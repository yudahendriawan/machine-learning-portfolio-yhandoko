# %% [markdown]
# <a href="https://colab.research.google.com/github/yudahendriawan/google-colab-projects/blob/image-classification/chessman_classification_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2024-01-30 13:31:21--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-01-30 13:31:21--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   178MB/s    in 0.3s
#
# 2024-01-30 13:31:21 (178 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Rook', 'King', 'Pawn', 'Bishop', 'Queen', 'Knight']

# %%
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total Queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total Rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
print('total Pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total King images : 76
# total Bishop images : 87
# total Queen images : 78
# total Rook images : 102
# total Pawn images : 107
# total Knight images : 106

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest',
    validation_split=0.1
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=8,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152V2

model = tf.keras.models.Sequential([
    # tf.keras.layers.Conv2D(64,(3,3), activation='relu',input_shape=(150,150,3)),
    # tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    # tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.4),
    # tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    # tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.4),
    ResNet152V2(weights='imagenet',include_top=False,input_tensor=Input(shape=(150,150,3))),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 2s 0us/step

# %%
model.compile(
    optimizer=tf.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
hist = model.fit(train_generator,
                 validation_data=validation_generator,
                 epochs=50,
                 verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 26s - loss: 8.4922 - accuracy: 0.4529 - val_loss: 2.8660 - val_accuracy: 0.5769 - 26s/epoch - 418ms/step
# Epoch 2/50
# 63/63 - 9s - loss: 2.2542 - accuracy: 0.6473 - val_loss: 2.1550 - val_accuracy: 0.5962 - 9s/epoch - 135ms/step
# Epoch 3/50
# 63/63 - 8s - loss: 1.1543 - accuracy: 0.7675 - val_loss: 1.3121 - val_accuracy: 0.7115 - 8s/epoch - 135ms/step
# Epoch 4/50
# 63/63 - 9s - loss: 0.7975 - accuracy: 0.8036 - val_loss: 0.8818 - val_accuracy: 0.8077 - 9s/epoch - 149ms/step
# Epoch 5/50
# 63/63 - 8s - loss: 0.8549 - accuracy: 0.8176 - val_loss: 1.2364 - val_accuracy: 0.7115 - 8s/epoch - 132ms/step
# Epoch 6/50
# 63/63 - 9s - loss: 0.5695 - accuracy: 0.8457 - val_loss: 0.7391 - val_accuracy: 0.7885 - 9s/epoch - 139ms/step
# Epoch 7/50
# 63/63 - 8s - loss: 0.5332 - accuracy: 0.8697 - val_loss: 0.9683 - val_accuracy: 0.7115 - 8s/epoch - 133ms/step
# Epoch 8/50
# 63/63 - 9s - loss: 0.5733 - accuracy: 0.8437 - val_loss: 0.9975 - val_accuracy: 0.7308 - 9s/epoch - 141ms/step
# Epoch 9/50
# 63/63 - 8s - loss: 0.4814 - accuracy: 0.8637 - val_loss: 1.0332 - val_accuracy: 0.8269 - 8s/epoch - 130ms/step
# Epoch 10/50
# 63/63 - 9s - loss: 0.7334 - accuracy: 0.8537 - val_loss: 1.6236 - val_accuracy: 0.6731 - 9s/epoch - 147ms/step
# Epoch 11/50
# 63/63 - 9s - loss: 0.4978 - accuracy: 0.8697 - val_loss: 1.0660 - val_accuracy: 0.6923 - 9s/epoch - 136ms/step
# Epoch 12/50
# 63/63 - 8s - loss: 0.4464 - accuracy: 0.8838 - val_loss: 0.5519 - val_accuracy: 0.8462 - 8s/epoch - 125ms/step
# Epoch 13/50
# 63/63 - 9s - loss: 0.2715 - accuracy: 0.9339 - val_loss: 0.6531 - val_accuracy: 0.8077 - 9s/epoch - 136ms/step
# Epoch 14/50
# 63/63 - 9s - loss: 0.3181 - accuracy: 0.9259 - val_loss: 1.3972 - val_accuracy: 0.7692 - 9s/epoch - 136ms/step
# Epoch 15/50
# 63/63 - 8s - loss: 0.3048 - accuracy: 0.9098 - val_loss: 0.6740 - val_accuracy: 0.8077 - 8s/epoch - 132ms/step
# Epoch 16/50
# 63/63 - 8s - loss: 0.2019 - accuracy: 0.9439 - val_loss: 0.9598 - val_accuracy: 0.8077 - 8s/epoch - 125ms/step
# Epoch 17/50
# 63/63 - 9s - loss: 0.3435 - accuracy: 0.9138 - val_loss: 0.8092 - val_accuracy: 0.8462 - 9s/epoch - 136ms/step
# Epoch 18/50
# 63/63 - 9s - loss: 0.3284 - accuracy: 0.9198 - val_loss: 0.8186 - val_accuracy: 0.8077 - 9s/epoch - 136ms/step
# Epoch 19/50
# 63/63 - 8s - loss: 0.3340 - accuracy: 0.9238 - val_loss: 1.0077 - val_accuracy: 0.7692 - 8s/epoch - 127ms/step
# Epoch 20/50
# 63/63 - 8s - loss: 0.4424 - accuracy: 0.8958 - val_loss: 0.9642 - val_accuracy: 0.7885 - 8s/epoch - 126ms/step
# Epoch 21/50
# 63/63 - 8s - loss: 0.2780 - accuracy: 0.9399 - val_loss: 0.7722 - val_accuracy: 0.8269 - 8s/epoch - 135ms/step
# Epoch 22/50
# 63/63 - 9s - loss: 0.2208 - accuracy: 0.9459 - val_loss: 0.9986 - val_accuracy: 0.7500 - 9s/epoch - 138ms/step
# Epoch 23/50
# 63/63 - 9s - loss: 0.3144 - accuracy: 0.9038 - val_loss: 1.8059 - val_accuracy: 0.7308 - 9s/epoch - 135ms/step
# Epoch 24/50
# 63/63 - 8s - loss: 0.3064 - accuracy: 0.9419 - val_loss: 1.5091 - val_accuracy: 0.7500 - 8s/epoch - 132ms/step
# Epoch 25/50
# 63/63 - 9s - loss: 0.2951 - accuracy: 0.9379 - val_loss: 1.7379 - val_accuracy: 0.5962 - 9s/epoch - 142ms/step
# Epoch 26/50
# 63/63 - 9s - loss: 0.2996 - accuracy: 0.9299 - val_loss: 0.9074 - val_accuracy: 0.8077 - 9s/epoch - 148ms/step
# Epoch 27/50
# 63/63 - 8s - loss: 0.1601 - accuracy: 0.9519 - val_loss: 0.7951 - val_accuracy: 0.7692 - 8s/epoch - 133ms/step
# Epoch 28/50
# 63/63 - 9s - loss: 0.2845 - accuracy: 0.9399 - val_loss: 0.7425 - val_accuracy: 0.8077 - 9s/epoch - 137ms/step
# Epoch 29/50
# 63/63 - 8s - loss: 0.1546 - accuracy: 0.9579 - val_loss: 1.2275 - val_accuracy: 0.7308 - 8s/epoch - 127ms/step
# Epoch 30/50
# 63/63 - 8s - loss: 0.1121 - accuracy: 0.9679 - val_loss: 0.8295 - val_accuracy: 0.8462 - 8s/epoch - 133ms/step
# Epoch 31/50
# 63/63 - 9s - loss: 0.2025 - accuracy: 0.9459 - val_loss: 1.8330 - val_accuracy: 0.7692 - 9s/epoch - 138ms/step
# Epoch 32/50
# 63/63 - 9s - loss: 0.1082 - accuracy: 0.9679 - val_loss: 1.0513 - val_accuracy: 0.7885 - 9s/epoch - 135ms/step
# Epoch 33/50
# 63/63 - 9s - loss: 0.3193 - accuracy: 0.9459 - val_loss: 1.3080 - val_accuracy: 0.7500 - 9s/epoch - 150ms/step
# Epoch 34/50
# 63/63 - 8s - loss: 0.1421 - accuracy: 0.9579 - val_loss: 1.0667 - val_accuracy: 0.8077 - 8s/epoch - 125ms/step
# Epoch 35/50
# 63/63 - 9s - loss: 0.1758 - accuracy: 0.9499 - val_loss: 0.5450 - val_accuracy: 0.8269 - 9s/epoch - 136ms/step
# Epoch 36/50
# 63/63 - 9s - loss: 0.1743 - accuracy: 0.9539 - val_loss: 0.4704 - val_accuracy: 0.8654 - 9s/epoch - 136ms/step
# Epoch 37/50
# 63/63 - 9s - loss: 0.2417 - accuracy: 0.9539 - val_loss: 0.7784 - val_accuracy: 0.8269 - 9s/epoch - 137ms/step
# Epoch 38/50
# 63/63 - 8s - loss: 0.1329 - accuracy: 0.9519 - val_loss: 1.3897 - val_accuracy: 0.7500 - 8s/epoch - 124ms/step
# Epoch 39/50
# 63/63 - 9s - loss: 0.1463 - accuracy: 0.9639 - val_loss: 1.1320 - val_accuracy: 0.8077 - 9s/epoch - 136ms/step
# Epoch 40/50
# 63/63 - 9s - loss: 0.2395 - accuracy: 0.9499 - val_loss: 1.0329 - val_accuracy: 0.8654 - 9s/epoch - 137ms/step
# Epoch 41/50
# 63/63 - 8s - loss: 0.1446 - accuracy: 0.9619 - val_loss: 0.9742 - val_accuracy: 0.8654 - 8s/epoch - 135ms/step
# Epoch 42/50
# 63/63 - 8s - loss: 0.2371 - accuracy: 0.9639 - val_loss: 1.5414 - val_accuracy: 0.7500 - 8s/epoch - 126ms/step
# Epoch 43/50
# 63/63 - 9s - loss: 0.3390 - accuracy: 0.9619 - val_loss: 2.2868 - val_accuracy: 0.8077 - 9s/epoch - 137ms/step
# Epoch 44/50
# 63/63 - 9s - loss: 0.3061 - accuracy: 0.9479 - val_loss: 1.7708 - val_accuracy: 0.6923 - 9s/epoch - 135ms/step
# Epoch 45/50
# 63/63 - 11s - loss: 0.1345 - accuracy: 0.9639 - val_loss: 0.9893 - val_accuracy: 0.8077 - 11s/epoch - 167ms/step
# Epoch 46/50
# 63/63 - 8s - loss: 0.2600 - accuracy: 0.9459 - val_loss: 1.3829 - val_accuracy: 0.7692 - 8s/epoch - 124ms/step
# Epoch 47/50
# 63/63 - 9s - loss: 0.1500 - accuracy: 0.9639 - val_loss: 0.8965 - val_accuracy: 0.7885 - 9s/epoch - 136ms/step
# Epoch 48/50
# 63/63 - 9s - loss: 0.1546 - accuracy: 0.9719 - val_loss: 1.1607 - val_accuracy: 0.7500 - 9s/epoch - 136ms/step
# Epoch 49/50
# 63/63 - 8s - loss: 0.1375 - accuracy: 0.9599 - val_loss: 1.0806 - val_accuracy: 0.7885 - 8s/epoch - 130ms/step
# Epoch 50/50
# 63/63 - 8s - loss: 0.0788 - accuracy: 0.9739 - val_loss: 1.0272 - val_accuracy: 0.8077 - 8s/epoch - 124ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
